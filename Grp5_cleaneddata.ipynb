# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install nbconvert

# %%
raw=pd.read_csv('D:/Harsha/US_ Checklist/UMBC/MIS/603/Term_Project/Airline_Passenger_Satisfication_traindata.csv')
raw.head(n=8)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
# 5           5  111157  Female     Loyal Customer   26  Personal Travel
# 6           6   82113    Male     Loyal Customer   47  Personal Travel
# 7           7   96462  Female     Loyal Customer   52  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
# ...

# %%
#read the data in the above cell

# %%
#data exploration 
data_store=raw.copy()
data_store.shape
# Out:
# (103904, 25)

# %%
data_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
data_store.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
#Data Preprocessing

# %%
data_store.nunique()
# Out:
# Unnamed: 0                           103904
# id                                   103904
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3802
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# Inflight service                          6
# ...

# %%
data_store['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
data_store.duplicated().sum()
# Out:
# 0

# %%
print('The number of duplicates datapoints in the found in the dataset are: ',data_store.duplicated().sum())
# Out:
# The number of duplicates datapoints in the found in the dataset are:  0

# %% [markdown]
# Removing Missing Values:

# %%
data_store.apply(lambda airline: sum(airline.isnull()))
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
data_store['Arrival Delay in Minutes'].nunique()
# Out:
# 455

# %% [markdown]
# The above number is the number of distinct delay in minutes by an airline service. It will be a difficult task to identify the arrival delay in minutes into a set of dummy variables. So we are going to remove this column

# %%
data_store=data_store.drop('Arrival Delay in Minutes',axis=1)

# %%
#sorted(set(data_store['Arrival Delay in Minutes'].dropna()))

# %%
#data_store[['Arrival Delay in Minutes']].head(10)

# %%
data_store.apply(lambda airline: sum(airline.isnull()))
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# # From the above step we can observe that the the feature with Arrival in Minutes with Null values have been removed from the data set

# %% [markdown]
# Now As We are having a feature in the first column that is unnamed before ID for test purpose I want to remove this column

# %% [markdown]
# #As the Null values have been removed the dataset available is now ready to use for further processess

# %%
data_cleaned=data_store.copy()

# %%
data_cleaned.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Seat comfort  \
# 0                                  4  ...             5
# 1                                  2  ...             1
# ...

# %%
data_cleaned.to_csv('D:/Harsha/US_ Checklist/UMBC/MIS/603/Term_Project/Cleaned_data.csv')
